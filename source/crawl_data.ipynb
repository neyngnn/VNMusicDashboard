# %% [markdown]
# <a href="https://colab.research.google.com/github/KamDaXay/Spotify/blob/main/Crawl_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Import Independencies**

# %%
# !pip install spotipy

# %%
import spotipy
from spotipy.oauth2 import SpotifyOAuth, SpotifyClientCredentials
import requests
import pandas as pd
from tqdm.auto import tqdm
import numpy as np

# %%
# df = pd.read_csv('Data.csv')
# track_uris = df.track_uri.tolist()
# len(track_uris)

# %%
# Tạo DataFrame với các cột được liệt kê, không cần giá trị
columns = ['Unnamed: 0', 'track_uri', 'track_name', 'artist_name', 'artist_pop',
           'artist_genres', 'album', 'track_pop', 'danceability', 'energy', 'key',
           'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
           'liveness', 'valence', 'tempo', 'id', 'duration_ms', 'time_signature',
           'date', 'checked_date', 'rock viet', 'vinahouse', 'viet edm',
           'mainland se asia metal', 'vietnamese bolero', 'indie viet',
           'vietnamese trap', 'vietnamese hip hop', 'viet remix', 'viet lo-fi',
           'viet instrumental', 'year', 'v_pop', 'v_rap']

# Khởi tạo DataFrame trống với các cột đã liệt kê
track_uris = pd.DataFrame(columns=columns)

# %%
# df.columns

# %% [markdown]
# # **Crawl Data**

# %%
#Authentication - without user
cid = 'd879045228fd441cac92e77bac2b0bdb' #'4585b2657bb742c1a422f8c509fe8a36'
secret = 'e46f4be556ce4dc79a6afe102ab38ef8' #'6a08c366154a4ad98cd4493c1540c852'
client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret)
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
temp = sp.playlist_tracks('https://open.spotify.com/playlist/37i9dQZF1DX0F4i7Q9pshJ')
temp.keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
temp['items'][0]['track'].keys()
# Out:
# dict_keys(['preview_url', 'available_markets', 'explicit', 'type', 'episode', 'track', 'album', 'artists', 'disc_number', 'track_number', 'duration_ms', 'external_ids', 'external_urls', 'href', 'id', 'name', 'popularity', 'uri', 'is_local'])

# %%
temp['items'][0]['track']
# Out:
# {'preview_url': 'https://p.scdn.co/mp3-preview/e8074297dcac85b5ef90f47bbce732dbd12387a2?cid=d879045228fd441cac92e77bac2b0bdb',
#  'available_markets': ['AR',
#   'AU',
#   'AT',
#   'BE',
#   'BO',
#   'BR',
#   'BG',
#   'CA',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DK',
#   'DO',
#   'DE',
#   'EC',
#   'EE',
#   'SV',
#   'FI',
#   'FR',
#   'GR',
#   'GT',
#   'HN',
#   'HK',
#   'HU',
#   'IS',
#   'IE',
#   'IT',
#   'LV',
#   'LT',
#   'LU',
#   'MY',
#   'MT',
#   'MX',
#   'NL',
#   'NZ',
#   'NI',
#   'NO',
#   'PA',
#   'PY',
#   'PE',
#   'PH',
#   'PL',
#   'PT',
#   'SG',
#   'SK',
#   'ES',
#   'SE',
#   'CH',
#   'TW',
#   'TR',
#   'UY',
#   'US',
#   'GB',
#   'AD',
#   'LI',
#   'MC',
#   'ID',
#   'JP',
#   'TH',
#   'VN',
#   'RO',
#   'IL',
#   'ZA',
#   'SA',
#   'AE',
#   'BH',
#   'QA',
#   'OM',
#   'KW',
#   'EG',
#   'MA',
#   'DZ',
#   'TN',
#   'LB',
#   'JO',
#   'PS',
#   'IN',
#   'KZ',
#   'MD',
#   'UA',
#   'AL',
#   'BA',
#   'HR',
# ...

# %%
temp['items'][1]['track']['album']['release_date']
# Out:
# '2024-06-08'

# %%
id
# Out:
# <function id(obj, /)>

# %%
temp['items'][0].keys()
# Out:
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])

# %%
sp.audio_features('spotify:track:3un8UkiPHJjlsrTHQnisXH')
# Out:
# [{'danceability': 0.768,
#   'energy': 0.325,
#   'key': 7,
#   'loudness': -11.863,
#   'mode': 1,
#   'speechiness': 0.15,
#   'acousticness': 0.133,
#   'instrumentalness': 7.69e-06,
#   'liveness': 0.174,
#   'valence': 0.525,
#   'tempo': 76.975,
#   'type': 'audio_features',
#   'id': '3un8UkiPHJjlsrTHQnisXH',
#   'uri': 'spotify:track:3un8UkiPHJjlsrTHQnisXH',
#   'track_href': 'https://api.spotify.com/v1/tracks/3un8UkiPHJjlsrTHQnisXH',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3un8UkiPHJjlsrTHQnisXH',
#   'duration_ms': 174545,
#   'time_signature': 4}]

# %%
cols = ['track_uri', 'track_name', 'artist_name', 'artist_pop',
        'artist_genres', 'album', 'track_pop', 'added_at',
        'danceability', 'energy', 'key', 'loudness',
        'mode', 'speechiness', 'acousticness', 'instrumentalness',
        'liveness', 'valence', 'tempo', 'type', 'id', 'duration_ms', 'time_signature', 'date']

def craw_fn(playlist_link, t_uris):

  df = pd.DataFrame(columns = cols)

  for i, pl_ in tqdm(enumerate(playlist_link)):
    playlist_URI = pl_.split("/")[-1].split("?")[0]

    try:
      songs = sp.playlist_tracks(playlist_URI)["items"]
    except:
      continue

    for track in songs:
      #URI
      track_uri = track["track"]["uri"]

      if track_uri not in t_uris:
        #t_uris.append(track_uri)
        t_uris = pd.concat([df, pd.DataFrame([new_row])], ignore_index=True)
        #Track name
        track_name = track["track"]["name"]

        #Main Artist
        artist_uri = track["track"]["artists"][0]["uri"]
        artist_info = sp.artist(artist_uri)

        #Name, popularity, genre
        artist_name = track["track"]["artists"][0]["name"]
        artist_pop = artist_info["popularity"]
        artist_genres = artist_info["genres"]

        #Album
        album = track["track"]["album"]["name"]

        #Popularity of the track
        track_pop = track["track"]["popularity"]

        # Duration
        duration = track['track']['duration_ms']

        # Added at
        added_at = track['added_at']

        # ID
        id = track['track']['id']

        release_date = track['track']['album']['release_date']

        # Audio Features
        au_ft = sp.audio_features(track_uri)[0]

        data = [track_uri, track_name, artist_name, artist_pop,
                artist_genres, album, track_pop, added_at,
                au_ft['danceability'], au_ft['energy'], au_ft['key'],
                au_ft['loudness'], au_ft['mode'], au_ft['speechiness'],
                au_ft['acousticness'], au_ft['instrumentalness'],
                au_ft['liveness'], au_ft['valence'], au_ft['tempo'],
                au_ft['type'], au_ft['id'],
                au_ft['duration_ms'], au_ft['time_signature'], release_date]

        temp = pd.DataFrame(columns=cols)
        temp.loc[-1] =data
        df = pd.concat([df, temp], axis=0, ignore_index=True)
  return df, t_uris

# %%
playlists = [
    'https://open.spotify.com/playlist/37i9dQZF1DX0F4i7Q9pshJ',
    'https://open.spotify.com/playlist/4pkof2WT0Spca1pX3j2dh4',
    'https://open.spotify.com/playlist/41BgMLI7GjGWBPH9tnBbq9',
    'https://open.spotify.com/playlist/5QrBH3L77cJOA0wAEGXqcc',
    'https://open.spotify.com/playlist/5DDEJSa3WwduUYN05a1AEm',
    'https://open.spotify.com/playlist/3vzmRJXtWHhEmZBWbmioZa?si=80a30b9000a541d4',
    'https://open.spotify.com/playlist/37i9dQZF1DXaXLLByTB5Ol',
    'https://open.spotify.com/playlist/37i9dQZF1EIcCojG1nHRnx',
    'https://open.spotify.com/playlist/37i9dQZF1DX4g8Gs5nUhpp',
    'https://open.spotify.com/playlist/37i9dQZF1DWVOaOWiVD1Lf',
    'https://open.spotify.com/playlist/37i9dQZF1DX0PE4eN3rxsW',
    'https://open.spotify.com/playlist/37i9dQZF1DX3XYbBdFxzGm',
    'https://open.spotify.com/playlist/37i9dQZF1EIX8lHNozBAMa',
    'https://open.spotify.com/playlist/37i9dQZF1DX5UMwGFV95IS',
    'https://open.spotify.com/playlist/37i9dQZF1DX8ndGHjS8CWd',
    'https://open.spotify.com/playlist/37i9dQZF1DWVbRrSFENdgA',
    'https://open.spotify.com/playlist/6uuwCj5wfqmJbv7eWdKVWl',
    'https://open.spotify.com/playlist/3tK9MCUIya89PgBowL8AzM',
    'https://open.spotify.com/playlist/37i9dQZF1DX4g8Gs5nUhpp',
]

playlist2=[
    'https://open.spotify.com/playlist/67BB9p2PhUcflOD11cpdMU',
    'https://open.spotify.com/playlist/37i9dQZF1DX9P2mIbvvSYB',
    'https://open.spotify.com/playlist/4to6jjsvMscVt8Ct3TkBHT',
    'https://open.spotify.com/playlist/37i9dQZF1DZ06evO0ExVQc?si=67b90e91cef14c1e',
    'https://open.spotify.com/playlist/37i9dQZF1DWT2oR9BciC32?si=fe6dda2cd1934519',
    'https://open.spotify.com/playlist/5q8BUSGnn9P1rsirdWEybA?si=c9e08ecbf89d46fd',
    'https://open.spotify.com/playlist/1vvcZAgnZBsedGqIxyEjrF',
    'https://open.spotify.com/playlist/37i9dQZF1DX0DaTVvjIMEq',
    'https://open.spotify.com/playlist/37i9dQZF1DX22YYiDtiJfD',
    'https://open.spotify.com/playlist/37i9dQZF1DXealDZnV5sQQ',
    'https://open.spotify.com/playlist/0YgxR9qv5eB9ZZvWaXpAYX',
    'https://open.spotify.com/playlist/02zSPmcae3ct4moT8om7kK',
    'https://open.spotify.com/playlist/37i9dQZF1DX0Bm9rVRYPcY',
    'https://open.spotify.com/playlist/37i9dQZF1DX3B7QboN6ESE',
    'https://open.spotify.com/playlist/37i9dQZF1DX29nkpzsmQhh'

]

# %%
playlists_3 =['https://open.spotify.com/album/2yFIVe82iVTpndgsVI22RD', 'https://open.spotify.com/album/6057VnkLOwHG5sdiaI2zck', 'https://open.spotify.com/album/6AewjbXphtFxTEVEeWfeTT',
             'https://open.spotify.com/album/07fsKWWWUMKdWmhzLZJUJp', 'https://open.spotify.com/album/3Sr0kzrgJfYKfX6CocvPLx', 'https://open.spotify.com/album/5Tkv9TAnCHTo9wctCmYKTY',
             'https://open.spotify.com/artist/0V2DfUrZvBuUReS1LFo5ZI', 'https://open.spotify.com/artist/2j3AXmye1FJXoGOXr6tufj', 'https://open.spotify.com/artist/2xvW7dgL1640K8exTcRMS4',
             'https://open.spotify.com/artist/3UjpgK0RqZLxsJqa4akrNn', 'https://open.spotify.com/artist/1pKJ2DU2i3uu6a23ngLUby', 'https://open.spotify.com/album/6cSYHzX6bKHsTmUxz90aXM',
             'https://open.spotify.com/album/2dZsaSnVn5i5uBg6FnhUVV', 'https://open.spotify.com/playlist/37i9dQZF1DX2sJEIionf29', 'https://open.spotify.com/playlist/37i9dQZF1DX8Lhs9IS5bF7']

playlists_4 = ['https://open.spotify.com/playlist/37i9dQZF1DWZshgEgoZFhY', 'https://open.spotify.com/playlist/37i9dQZF1DXbbp0uiGXEBw', 'https://open.spotify.com/playlist/37i9dQZF1DWYLMi9ZNZUaz',
              'https://open.spotify.com/playlist/37i9dQZF1DXcJ3YhsMrHLi', 'https://open.spotify.com/playlist/37i9dQZF1DWYXdFGkgrNCC', 'https://open.spotify.com/playlist/37i9dQZF1DX35hqM16st8Y',
             'https://open.spotify.com/album/6Y6VgkXEYhFNsIjFgbd2OG', 'https://open.spotify.com/album/6nsWBtaENkGvPLjW5vo8zh', 'https://open.spotify.com/album/1y0a68Fnw5lN9GZwrQcr3q',
             'https://open.spotify.com/playlist/37i9dQZF1DXealDZnV5sQQ', 'https://open.spotify.com/album/0isNJzCI4Zng8GpQjGGXyv', 'https://open.spotify.com/album/1CIlcETQdT2BEbFXZRgbMg',
             'https://open.spotify.com/playlist/37i9dQZF1DWZkXKJRqhQ3a', 'https://open.spotify.com/album/4jtVvv19wqv5RZxx1CtVtD', 'https://open.spotify.com/album/2WwTgqDvhOmo7cRU0TDJoP']

playlists_5 =['https://open.spotify.com/album/59Py5klEYyB3CNs4MalJTC', 'https://open.spotify.com/album/7hOecuasKeecLanueJlvxE', 'https://open.spotify.com/playlist/37i9dQZF1DWWdlSG3xntgM,'
             'https://open.spotify.com/playlist/37i9dQZF1DX7P0FWNtYXvJ', 'https://open.spotify.com/album/20hpRAF1vJyA9Svfa5di1H',
             'https://open.spotify.com/album/3GvpjJOmKq6dDiBlLIRiMy', 'https://open.spotify.com/album/3sHBIwxUOFP8AGhIWujfTA', 'https://open.spotify.com/playlist/37i9dQZF1DXawFHCeXzoCQ', 'https://open.spotify.com/album/0EohUiIviSghwQYa2rJ8dN']

# %%
playlists_1 = ['https://open.spotify.com/playlist/37i9dQZF1DWVOaOWiVD1Lf', 'https://open.spotify.com/playlist/37i9dQZF1DX4g8Gs5nUhpp', 'https://open.spotify.com/playlist/37i9dQZF1DX1e2VSJFudND',
             'https://open.spotify.com/playlist/37i9dQZF1DX5UMwGFV95IS', 'https://open.spotify.com/playlist/37i9dQZF1DX3e9b2XMiQ6I', 'https://open.spotify.com/playlist/37i9dQZF1DWUTZW9htiAv9',
             'https://open.spotify.com/playlist/37i9dQZF1DX0PE4eN3rxsW', 'https://open.spotify.com/playlist/37i9dQZF1DWVbRrSFENdgA', 'https://open.spotify.com/playlist/37i9dQZF1DX8ndGHjS8CWd',
             'https://open.spotify.com/playlist/37i9dQZF1DWUYe7oajVI3W', 'https://open.spotify.com/playlist/37i9dQZF1DX6sCJFCJIfiB', 'https://open.spotify.com/playlist/37i9dQZF1DWYshp3qt6eyW',
             'https://open.spotify.com/playlist/37i9dQZF1DX3lnqcg5MsPa', 'https://open.spotify.com/playlist/37i9dQZF1DWVGqd3X7g31u', 'https://open.spotify.com/playlist/37i9dQZF1DX9QVp4mlz2lk',
             'https://open.spotify.com/playlist/37i9dQZF1DWZkXKJRqhQ3a', 'https://open.spotify.com/playlist/37i9dQZF1DX3pJ8DlmnZlN', 'https://open.spotify.com/playlist/37i9dQZF1DX1kCQJbQlZlA']

df_1 = craw_fn(playlists_1, track_uris)
# Out:
# 0it [00:00, ?it/s]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-42-3bfb38a0d037> in <cell line: 8>()
#       6              'https://open.spotify.com/playlist/37i9dQZF1DWZkXKJRqhQ3a', 'https://open.spotify.com/playlist/37i9dQZF1DX3pJ8DlmnZlN', 'https://open.spotify.com/playlist/37i9dQZF1DX1kCQJbQlZlA']
#       7
# ----> 8 df_1 = craw_fn(playlists_1, track_uris)
#
# <ipython-input-39-f2624b80042c> in craw_fn(playlist_link, t_uris)
#      22
#      23       if track_uri not in t_uris:
# ---> 24         t_uris.append(track_uri)
#      25         #Track name
#      26         track_name = track["track"]["name"]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#    5990
# ...

# %%
df_1

# %%
playlists_2 = ['https://open.spotify.com/playlist/37i9dQZF1DX1vC8WamgJcA', 'https://open.spotify.com/playlist/37i9dQZF1DX35zmlYTBMjk', 'https://open.spotify.com/playlist/37i9dQZF1DX4sVHGDd3pW3',
             'https://open.spotify.com/playlist/37i9dQZF1DX7sUtJC5lRfJ', 'https://open.spotify.com/album/4qq4etmVjwA2jjIxdfi6Hu', 'https://open.spotify.com/album/4CnbwNWknsf3SqWSxskeT2',
             'https://open.spotify.com/album/6eKLoMhcXDWiC1FLBqH8A2', 'https://open.spotify.com/album/5txOWXuNQIeSSSaxs7GAJl', 'https://open.spotify.com/album/6Sa7xLUXSu2ifGNdK3LkSt',
             'https://open.spotify.com/album/7788CNXg3SIMnDvJ6IlOMF', 'https://open.spotify.com/album/264FYADumRCTiRbU26d3Ni', 'https://open.spotify.com/album/5OjVazsR3dsFkZCkGOGOMl',
             'https://open.spotify.com/album/5PVhEJoDtcHFMgFPaX3JQi', 'https://open.spotify.com/album/7A3c3SyC4KaDuAnGA2uYbC', 'https://open.spotify.com/album/1UkRSStTl7cIy7OCHPsmbA']
df_2, track_uris = craw_fn(playlists_2, track_uris)

# %%
df_3, track_uris = craw_fn(playlists_5, track_uris)

# %%
df_4, track_uris = craw_fn(playlists_3, track_uris)

# %%
df_5, track_uris = craw_fn(playlists_4, track_uris)

# %% [markdown]
# # Test

# %%
df_combined
